# %%
import random

import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

from display_researching import display_ridge_alpha

# %%
data = pd.read_csv('datasets/reglab1.txt', sep='\t')
X = data.loc[:, ['x', 'y']]
y = data['z']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=random.randint(0, 1000))

# least squares Linear Regression
lmr = LinearRegression().fit(X_train, y_train)
y_pred = lmr.predict(X_test)
print('linear train {}'.format(lmr.score(X_train, y_train)))
print('linear test {}'.format(lmr.score(X_test, y_test)))
print('linear mse test {}'.format(mean_squared_error(y_test, y_pred)))
# Out:
# linear train 0.9675500295143366
# linear test 0.9710039652351741
# linear mse test 0.11430475333018211

# %%
# ridge Linear Regression
display_ridge_alpha(X, y)

# %%
rlr = Ridge(alpha=0.1).fit(X_train, y_train)
y_pred = rlr.predict(X_test)
print('ridge train {}'.format(rlr.score(X_train, y_train)))
print('ridge test {}'.format(rlr.score(X_test, y_test)))
print('ridge mse test {}'.format(mean_squared_error(y_test, y_pred)))
# Out:
# ridge train 0.9674861687559062
# ridge test 0.970763220156851
# ridge mse test 0.11525379022492847

# %%
llr = Lasso(alpha=1).fit(X_train, y_train)
y_pred = llr.predict(X_test)
print('lasso train {}'.format(llr.score(X_train, y_train)))
print('lasso test {}'.format(llr.score(X_test, y_test)))
print('lasso mse test {}'.format(mean_squared_error(y_test, y_pred)))
# Out:
# lasso train 0.0
# lasso test -0.0007210290833972177
# lasso mse test 3.9449245839801064

# %%
# elastic net Linear Regression
# display_elasticnet_alpha(X, y)
enlr = ElasticNet(alpha=1, l1_ratio=0.5).fit(X_train, y_train)
y_pred = enlr.predict(X_test)
print('ElasticNet train {}'.format(enlr.score(X_train, y_train)))
print('ElasticNet test {}'.format(enlr.score(X_test, y_test)))
print('ElasticNet mse test {}'.format(mean_squared_error(y_test, y_pred)))
# Out:
# ElasticNet train 0.0
# ElasticNet test -0.0007210290833972177
# ElasticNet mse test 3.9449245839801064
